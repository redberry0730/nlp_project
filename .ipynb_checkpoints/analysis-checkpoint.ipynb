# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (3.7.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy) (6.4.0)
# Requirement already satisfied: setuptools in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy) (65.5.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: jinja2 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy) (2.5.2)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy) (0.3.4)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: numpy>=1.19.0 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy) (1.26.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy) (1.1.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy) (4.66.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy) (8.2.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy) (2.31.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy) (0.9.0)
# Requirement already satisfied: packaging>=20.0 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy) (23.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.8.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.14.5)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from jinja2->spacy) (2.1.3)
#
# [notice] A new release of pip available: 22.3.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 29.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from en-core-web-sm==3.7.1) (3.7.2)
# Requirement already satisfied: packaging>=20.0 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.5.2)
# Requirement already satisfied: numpy>=1.19.0 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: jinja2 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.1)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.1)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: setuptools in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (65.5.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.8.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.14.5)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/kevinkoh/Desktop/textproc/venv/lib/python3.10/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.3)
#
# [notice] A new release of pip available: 22.3.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import re
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import json
from bs4 import BeautifulSoup
from nltk import pos_tag, word_tokenize
from nltk.tokenize import sent_tokenize
import string

# %%
# load messi data into single string
messi_file_path = 'data/messi.json'

with open(messi_file_path, 'r') as file:
    messidata = json.load(file)

messitotalstring = ' '.join(messidata)

soup = BeautifulSoup(messitotalstring, 'html.parser')

p_tags = soup.find_all('p')

messistring=''
for tag in p_tags:
    messistring+=tag.get_text()+' '

messistring = re.sub("\n", " ", messistring)
messistring = re.sub("\s+", " ", messistring)
messistring = re.sub("\[.*?\]", " ", messistring)
messistring = messistring.lower()

# %%
# load trout data into single string
trout_file_path = 'data/trout.json'

with open(trout_file_path, 'r') as file:
    troutdata = json.load(file)

trouttotalstring = ' '.join(troutdata)

soup = BeautifulSoup(trouttotalstring, 'html.parser')

p_tags = soup.find_all('p')

troutstring=''
for tag in p_tags:
    troutstring+=tag.get_text()+' '

troutstring = re.sub("\n", " ", troutstring)
troutstring = re.sub("\s+", " ", troutstring)
troutstring = re.sub("\[.*?\]", " ", troutstring)
troutstring = troutstring.lower()

# %%
# load lebron data into single string
lebron_file_path = 'data/lebron.json'

with open(lebron_file_path, 'r') as file:
    lebrondata = json.load(file)

lebrontotalstring = ' '.join(lebrondata)

soup = BeautifulSoup(lebrontotalstring, 'html.parser')

p_tags = soup.find_all('p')

lebronstring=''
for tag in p_tags:
    lebronstring+=tag.get_text()+' '

lebronstring = re.sub("\n", " ", lebronstring)
lebronstring = re.sub("\s+", " ", lebronstring)
lebronstring = re.sub("\[.*?\]", " ", lebronstring)
lebronstring = lebronstring.lower()

# %%
# load mahomes data into single string
mahomes_file_path = 'data/mahomes.json'

with open(mahomes_file_path, 'r') as file:
    mahomesdata = json.load(file)

mahomestotalstring = ' '.join(mahomesdata)

soup = BeautifulSoup(mahomestotalstring, 'html.parser')

p_tags = soup.find_all('p')

mahomesstring=''
for tag in p_tags:
    mahomesstring+=tag.get_text()+' '

mahomesstring = re.sub("\n", " ", mahomesstring)
mahomesstring = re.sub("\s+", " ", mahomesstring)
mahomesstring = re.sub("\[.*?\]", " ", mahomesstring)
mahomesstring = mahomesstring.lower()

# %%
# load crosby data into single string
crosby_file_path = 'data/crosby.json'

with open(crosby_file_path, 'r') as file:
    crosbydata = json.load(file)

crosbytotalstring = ' '.join(crosbydata)

soup = BeautifulSoup(crosbytotalstring, 'html.parser')

p_tags = soup.find_all('p')

crosbystring=''
for tag in p_tags:
    crosbystring+=tag.get_text()+' '

crosbystring = re.sub("\n", " ", crosbystring)
crosbystring = re.sub("\s+", " ", crosbystring)
crosbystring = re.sub("\[.*?\]", " ", crosbystring)
crosbystring = crosbystring.lower()

# %%
messitokens = nltk.word_tokenize(messistring)
lebrontokens = nltk.word_tokenize(lebronstring)
trouttokens = nltk.word_tokenize(troutstring)
mahomestokens = nltk.word_tokenize(mahomesstring)
crosbytokens = nltk.word_tokenize(crosbystring)

# %%
print('Length of Messi Tokens:', len(messitokens))
print('Length of Lebron Tokens:', len(lebrontokens))
print('Length of Trout Tokens:', len(trouttokens))
print('Length of Mahomes Tokens:', len(mahomestokens))
print('Length of Crosby Tokens:', len(crosbytokens))

total = len(messitokens)+len(lebrontokens)+len(trouttokens)+len(mahomestokens)+len(crosbytokens)
print('Length of All Tokens:', total)
# Out:
# Length of Messi Tokens: 233613
# Length of Lebron Tokens: 60329
# Length of Trout Tokens: 94955
# Length of Mahomes Tokens: 120312
# Length of Crosby Tokens: 23903
# Length of All Tokens: 533112

# %%
# compiling list of stopwords

punctuation_stop_list = string.punctuation

# originial list of stop words
stoplist = stopwords.words("english")

# adding more stop words
stoplist.extend([
    "a", "about", "above", "after", "again", "against", "all", "am", "an", "and", "any", "are", "aren't", "as", "at", 
    "be", "because", "been", "before", "being", "below", "between", "both", "but", "by", 
    "can't", "cannot", "could", "couldn't", 
    "did", "didn't", "do", "does", "doesn't", "doing", "don't", "down", "during", 
    "each", 
    "few", "for", "from", "further", 
    "had", "hadn't", "has", "hasn't", "have", "haven't", "having", "he", "he'd", "he'll", "he's", "her", "here", "here's", "hers", "herself", "him", "himself", "his", "how", "how's", 
    "i", "i'd", "i'll", "i'm", "i've", "if", "in", "into", "is", "isn't", "it", "it's", "its", "itself", 
    "let's", 
    "me", "more", "most", "mustn't", "my", "myself", 
    "no", "nor", "not", 
    "of", "off", "on", "once", "only", "or", "other", "ought", "our", "ours", "ourselves", "you", "you'd", "you'll", "you're", "you've", "your", "yours", "yourself", "yourselves",
    ".", ",", "'s", "--", "n't", "ha", "wa"
])

# adding punctuation
stoplist.extend(punctuation_stop_list)

# adding more punctuation
stoplist.extend(["''", '``'])

stopwords = set(stoplist)

# %%
import spacy

# Load the spaCy model
nlp = spacy.load("en_core_web_sm")
nlp.max_length = 1200000

index=['Messi', 'Lebron', 'Trout', 'Crosby', 'Mahomes']

# Your texts
texts = [" ".join(messitokens), " ".join(lebrontokens), " ".join(trouttokens), " ".join(crosbytokens), " ".join(mahomestokens)]

# Function to extract adjectives from a single document
def extract_adjectives(text):
    doc = nlp(text)
    return [token.text for token in doc if token.pos_ == "ADJ"]

# Extract adjectives from each text
adjectives_per_text = [extract_adjectives(text) for text in texts]

# If you want to see the adjectives for each athlete
for x in range(len(index)):
    print(index[x])
    print(adjectives_per_text[x])
# Out:
# Messi
# ['first', 'more', 'incredible', 'happy', 'hard', 'leo', 'many', 'happy', 'least', 'more', 'first', 'extraordinary', 'good', 'unstoppable', 'difficult', 'crazy', 'former', 'muscular', 'record', 'foreseeable', 'little', 'left', 'only', 'long', 'next', 'small', 'next', 'rival', 'upper', 'upper', 'upper', 'more', 'small', 'opener', '2nd', 'last', 'red', 'little', 'most', 'next', 'regular', 'better', 'ordinary', 'little', 'less', 'old', 'red', 'only', 'former', 'first', 'full', 'associated', 'final', '78th', 'more', 'last', 'well', 'first', 'violent', 'first', 'competitive', 'former', 'usual', 'delighted', 'first', 'historic', 'nice', 'strong', 'second', 'long', 'rival', 'friendly', 'great', 'rival', 'last', 'last', 'social', 'exact', 'more', 'inaccurate', 'global', 'first', 'international', 'earlier', 'unlikely', 'last', 'global', 'main', 'international', 'saudi', 'general', 'major', 'big', 'biggest', 'messi', 'rich', 'last', 'last', 'other', 'last', 'portugal', 'great', 'french', 'unauthorised', 'last', 'first', '-', 'greatest', 'other', 'biggest', 'prime', 'barcelona', 'real', 'european', 'little', 'portugal', 'next', 'european', 'next', 'more', 'mitrovic', 'sergej', 'milinkovic', 'first', 'round', 'ready', 'second', 'late', 'more', 'logistical', 'international', 'first', 'messi', 'global', 'front', 'fierce', 'south', 'false', 'argentine', 'sure', 'creative', 'different', 'impossible', 'extra', 'first', 'key', 'young', 'true', 'great', 'great', 'final', 'last', 'south', 'american', 'heavy', 'long', 'great', 'prepared', 'best', 'best', 'biggest', 'messi', 'long', 'best', 'great', 'own', 'personal', 'black', 'real', 'madrid', 'last', 'impoverished', 'anti', '-', 'racism', 'educational', 'inclusive', 'foster', 'old', 'special', 'anti', '-', 'racism', 'harsher', 'discriminatory', 'racist', 'first', 'more', 'first', 'clear', 'late', 'last', 'relative', 'good', '70th', 'misleading', 'key', 'experienced', 'significant', 'top', 'great', 'fond', 'last', 'first', 'major', 'old', 'great', 'great', 'tough', 'historic', 'final', 'first', 'available', 'final', 'worth', 'more', 'valuable', 'final', 'quarterfinal', 'final', 'sant', 'barcelona', 'rare', 'able', 'free', 'greatest', 'valiant', 'greatest', 'modern', 'monumental', 'invaluable', 'sheer', 'highest', 'kylian', 'epic', 'final', 'best', 'best', 'eighth', 'former', 'treble', 'ligue', 'true', 'good', 'likely', 'top', 'fifth', 'administrative', 'sixth', 'bad', 'unprecedented', 'consecutive', 'worst', 'more', 'predictable', 'unorthodox', 'national', 'previous', 'least', 'last', 'little', 'previous', 'defensive', 'current', 'more', 'entire', 'more', 'bottom', 'last', 'much', 'credible', 'luis', 'many', 'conservative', 'extra', 'likely', 'front', 'international', 'hot', 'same', 'fascinating', 'easy', 'other', 'dramatic', 'full', 'such', 'good', 'painful', 'own', 'consolidated', 'magnificent', 'last', 'final', 'entire', 'suspect', 'back', 'final', 'true', 'single', 'little', 'good', 'true', 'able', 'major', 'quick', 'second', 'cool', 'defensive', 'more', 'true', 'second', 'consecutive', 'aware', 'next', 'more', 'clear', 'long', 'encouraging', 'same', 'true', 'first', 'extra', 'young', 'unruly', 'first', 'more', 'obscene', '23rd', 'young', 'good', 'good', 'national', 'intense', 'hard', 'little', '19th', 'right', 'left', 'normal', 'difficult', 'intense', 'physical', 'fast', 'comfortable', 'unbeaten', 'former', 'national', 'second', 'big', 'new', 'first', 'competitive', 'last', 'more', 'national', 'recognizable', 'good', 'second', 'aggressive', 'intense', 'difficult', 'physical', 'fast', 'comfortable', 'long', 'fast', 'best', 'low', 'opener', 'half', 'second', 'historic', 'first', 'away', 'unbeaten', 'comfortable', 'physical', 'good', 'close', 'uruguayan', 'national', 'second', 'same', 'associated', 'full', 'dual', 'respective', 'social', 'viral', 'few', 'other', 'more', 'iconic', 'new', 'new', 'chart', 'due', 'joint', 'next', 'latest', 'first', 'shooter', 'chock', 'full', 'cultural', 'original',  ...
# Lebron
# ['more', 'lopsided', 'regular', 'longer', 'usual', 'old', 'much', 'largest', 'largest', 'pressing', 'main', 'good', 'fourth', 'overall', 'particular', 'first', 'familiar', 'early', 'big', 'quick', 'little', 'best', 'deep', 'colorful', 'wrong', 'better', 'thorough', 'personal', 'regular', 'previous', 'frank', 'volatile', 'pointed', 'entire', 'personal', 'fourth', 'tyrese', 'several', 'obvious', 'unavailable', 'good', 'western', 'next', 'short', 'competitive', 'high', 'personal', 'identifiable', 'same', 'vintage', 'consecutive', 'fourth', 'former', 'charitable', 'responsible', 'able', 'old', 'old', 'fist', 'first', 'lengthy', 'many', 'sellout', 'old', 'cool', 'cool', 'first', 'golden', 'regular', 'first', 'unanimous', 'best', 'major', 'early', 'huge', 'right', 'able', 'double', 'high', 'more', 'old', 'special', 'special', 'able', 'first', 'special', 'decent', 'new', 'general', 'oversize', 'white', 'biggest', 'cool', 'more', 'stat', 'more', 'clutch', 'past', 'personal', 'least', 'cool', 'able', 'able', 'proud', 'proud', 'able', 'great', 'proud', 'sure', 'high', 'free', 'rare', 'old', 'madden', '108th', 'free', 'right', 'thunderous', 'fourth', 'open', 'satisfied', 'open', 'open', 'willing', 'recent', 'own', 'fourth', 'third', 'technical', 'fourth', 'small', 'young', 'financial', 'more', 'historical', 'more', 'wilt', 'efficient', 'overall', 'better', 'best', 'best', 'able', 'more', 'past', 'last', 'able', 'quick', '20th', 'eldest', 'cardiac', 'unmistakable', 'special', 'bad', 'oldest', 'usc', 'able', 'first', 'bronny', 'little', 'outstanding', 'special', 'wide', 'nike', 'clean', 'good', 'fred', 'main', 'white', 'similar', 'icy', 'white', 'nike', 'favorite', 'first', 'nike', 'nike', 'left', 'first', 'first', 'unintentional', 'left', 'slight', 'sore', 'questionable', 'last', 'proactive', 'major', 'next', 'high', '21st', 'questionable', 'left', 'first', 'unintentional', 'left', 'slight', 'sore', 'sure', 'loose', 'possible', 'effective', 'sore', 'slow', 'high', '21st', '21st', 'capable', 'best', 'old', 'first', 'unprecedented', 'short', 'other', 'salient', 'recent', 'most', 'second', 'last', 'old', 'indianapolis', 'premature', 'final', 'final', 'more', 'super', 'significant', 'long', 'final', 'highest', 'single', 'full', 'later', 'many', 'straight', 'full', 'higher', 'highest', 'terrified', 'intentional', 'final', 'sixth', 'apparent', 'late', 'off', 'straight', 'best', 'epic', 'consistent', 'greatest', 'high', 'few', 'swift', 'final', 'best', 'old', 'final', 'better', 'true', 'old', 'young', 'few', 'next', 'most', 'straight', 'old', 'sure', 'exact', 'complete', 'first', 'black', 'old', 'single', 'alone', 'last', 'few', 'great', 'open', 'sixth', 'final', 'slight', 'late', 'painful', 'first', 'durant', 'durant', 'epic', 'durant', 'durant', 'fourth', 'open', 'unintentional', 'durant', 'first', 'durant', 'left', 'sore', 'slight', 'sure', 'loose', 'possible', 'effective', 'sore', 'first', 'first', 'little', 'great', 'second', 'last', 'young', 'good', 'better', 'main', 'big', 'second', 'biggest', 'offensive', 'fourth', 'first', 'able', 'able', 'later', 'good', 'huge', 'little', 'rival', 'regular', 'big', 'ongoing', 'ncaa', 'former', 'defensive', 'first', 'second', 'third', 'fourth', 'able', 'able', 'key', 'best', 'able', 'able', 'final', 'few', 'temecula', 'exclusive', 'individual', 'free', 'hard', 'big', 'noticeable', 'christian', 'little', 'big', 'general', 'front', 'more', 'free', 'first', 'big', 'common', 'interior', 'dynamic', 'open', 'failsafe', 'consistent', 'prescient', 'small', 'switchable', 'positionless', 'best', 'big', 'past', 'past', 'close', 'possible', 'second', 'significant', 'first', 'willing', 'second', 'preferred', 'same', 'best', 'last', 'western', 'eventual', 'skilled', 'elite', 'stark', 'past', 'several', 'first', 'complete', 'seventh', 'second', 'major', 'montrezl', 'ninth', 'right', 'final', 'new', 'first', 'big', 'regular', 'undrafted', 'big', 'big', 'old', 'old', 'other', 'better', 'close', 'twin', 'playful', 'other ...
# Trout
# ['free', 'likely', 'few', 'big', 'right', 'mlb', 'available', 'next', 'most', 'past', 'significant', 'main', 'major', 'ready', 'top', 'younger', 'international', 'frequent', 'likely', 'teoscar', 'free', 'perfect', 'upper', 'surprising', 'serious', 'top', 'triple', 'former', 'top', 'first', 'pete', 'full', 'easy', 'hesitant', 'huge', 'first', 'free', 'past', 'first', 'older', 'better', 'good', 'first', 'deepest', 'former', 'key', 'next', 'first', 'most', 'young', 'easy', 'rookie', 'uncomfortable', 'full', 'hard', 'handed', 'willing', 'only', 'big', 'big', 'more', 'bad', 'other', 'other', 'sure', 'bold', 'older', 'prone', 'big', 'semi', '-', 'homecoming', 'final', 'free', 'good', 'other', 'second', 'more', 'big', 'hard', 'higher', 'small', 'most', 'second', 'second', 'good', 'worst', 'second', 'low', 'most', 'fine', 'free', 'third', 'second', 'free', 'free', 'glasnow', 'free', 'front', 'ready', 'second', 'high', 'particular', 'hellacious', 'enough', 'effective', 'likely', 'more', 'giant', 'long', 'risky', 'free', 'free', 'desperate', 'infield', 'desperate', 'primary', 'better', 'deep', 'big', 'many', 'first', 'buzz', 'sonny', 'rental', 'enough', 'top', 'striking', 'close', 'fit', 'easier', 'schoenfield', 'right', 'tony', 'only', 'sure', 'hopeful', 'previous', 'little', 'potential', 'major', 'ready', 'ryan', 'double', 'big', 'second', 'long', 'non', '-', 'prime', 'ok', 'other', 'best', 'shane', 'least', 'close', 'last', 'allen', 'cal', 'winnable', 'best', 'inclined', 'overwhelmed', 'huge', 'top', 'real', 'big', 'long', 'top', 'first', 'first', 'front', 'cold', 'final', 'final', 'disappointing', 'successful', 'close', 'good', 'past', 'better', 'regular', 'little', 'better', 'wild', 'fetched', 'last', 'general', 'excited', 'best', 'best', 'open', 'clear', 'ready', 'firm', 'new', 'free', 'likely', 'whole', 'top', 'free', 'comparable', 'tremendous', 'open', 'right', 'regular', 'spectacular', 'poor', 'to-5', 'big', 'next', 'able', 'center', 'marsh', 'right', 'rojas', 'cristian', 'little', 'overrated', 'final', 'final', 'fourth', 'eighth', 'friendly', '14th', 'good', 'great', 'least', 'hot', 'first', 'unstoppable', 'first', 'long', 'first', 'centric', 'ultimate', 'last', 'worst', 'bryce', 'only', 'other', 'regular', 'past', 'third', 'aaron', 'many', 'many', 'lowest', 'better', 'ninth', 'strikeout', 'chase', 'worst', 'nice', 'subpar', 'worth', 'streaky', 'past', 'big', 'past', 'best', 'best', 'hard', 'little', 'little', 'more', 'veteran', 'best', 'plenty', 'good', 'more', 'best', 'unique', 'least', 'different', 'troublesome', 'broken', 'cozy', 'hard', 'bigger', 'potential', 'middle', 'next', 'enormous', 'worth', 'zack', 'free', 'next', 'net', 'free', 'same', 'free', 'sonny', 'marcus', 'less', 'much', 'greatest', 'simple', 'right', 'ohtani', 'speedy', 'single', 'high', 'tough', 'rojas', 'clear', 'long', 'only', 'future', 'ohtani', 'unlikely', 'first', 'stuck', 'more', 'better', 'free', 'pete', 'unlikely', 'ohtani', 'late', 'third', 'straight', 'evident', 'major', 'first', 'japanese', 'top', 'nike', 'top', 'top', 'top', 'free', 'last', 'much', 'final', 'oblique', 'ohtani', 'top', 'emotional', 'recent', 'recent', 'greatest', 'fewer', 'past', 'frustrating', 'tough', 'hard', 'first', 'full', 'other', 'little', 'more', 'troublesome', 'healthy', 'great', 'freak', 'bottom', 'left', '.263/.367/.490', 'right', 'few', 'extra', 'healthy', 'more', 'recent', 'difficult', 'former', 'general', 'front', 'near', 'private', 'front', 'clear', 'ready', 'similar', 'private', 'same', 'clear', 'ready', 'uniform', 'final', 'regular', 'eighth', 'consecutive', 'second', 'front', 'ailing', 'thin', 'nightmarish', 'ulnar', 'ohtani', 'oblique', 'free', 'quiet', 'own', 'right', 'possible', 'past', 'next', 'young', 'such', 'neto', 'first', 'next', 'utmost', 'healthy', 'more', 'hard', 'positive', 'left', 'next', 'last', 'dry', 'right', 'fewer', 'past', 'last', 'dry', 'left', 'next', 'dry', 'good', 'hard', 'next', 'few', 'next', 'live', 'randal', 'ninth', 'high', 'square ...
# Crosby
# ['latest', 'greatest', 'american', 'active', 'free', 'ready', 'early', 'serious', 'healthy', 'last', 'right', 'right', 'serious', 'few', 'intriguing', 'buffalo', 'personal', 'few', 'open', 'early', 'most', 'former', 'favorite', 'interested', 'last', 'sleeper', 'clear', 'bottom', 'short', 'low', 'first', 'good', 'last', 'first', 'optimistic', 'unknown', 'uncharted', 'last', 'old', 'last', 'right', 'enough', 'dramatic', 'first', 'front', 'arturas', 'most', 'ready', 'better', 'dedicated', 'medical', 'excited', 'landeskog', 'intense', 'such', 'good', 'few', 'optimistic', 'early', 'cautious', 'landeskog', 'best', 'long', 'best', 'young', 'old', 'past', 'few', 'thin', 'dual', 'second', 'good', 'quiet', 'credited', 'friendly', 'funny', 'last', 'junior', 'professional', '10th', 'third', 'worst', 'next', 'serious', 'much', 'old', 'professional', 'many', 'first', 'first', 'second', 'general', 'incredible', 'new', 'dreaded', 'more', 'important', 'selfish', 'selfless', 'more', 'future', 'extra', 'same', 'excellent', 'open', 'afraid', 'hard', 'more', 'perfect', 'lethal', 'able', 'past', 'new', 'more', 'several', 'real', 'bottom', 'ready', 'quick', 'elite', 'future', 'sure', 'guentzel', 'old', 'final', 'better', 'first', 'least', 'first', 'conservative', 'medical', 'top', 'top', 'defensive', 'last', 'many', 'first', 'first', 'simple', 'first', 'longest', 'angry', 'hungry', 'balanced', 'flat', 'several', 'ian', 'early', 'big', 'difficult', 'mega', 'free', 'same', 'different', 'little', 'other', 'worth', 'current', 'dramatic', 'first', 'new', 'potential', 'appropriate', 'fourth', 'intriguing', 'excited', 'special', 'legitimate', 'top', 'better', 'other', 'necessary', 'financial', 'considerable', 'full', 'last', 'simplest', 'transparent', 'many', 'better', 'whole', 'montreal', 'peculiar', 'epic', 'eastern', 'double', 'other', 'other', 'other', 'little', 'many', 'easier', 'fierce', 'personal', 'funny', 'chatty', 'early', 'great', 'funny', 'odd', 'rare', 'longer', 'old', '19th', 'stately', 'gray', 'full', 'enough', 'last', 'single', 'other', 'average', 'old', 'highest', 'public', 'post', '-', 'crosby', 'current', 'center', 'unrestricted', 'free', 'multiyear', 'new', 'holy', 'best', 'last', 'little', 'free', 'same', 'other', 'great', 'first', 'new', 'eighth', 'introductory', 'average', 'higher', 'greatest', 'offensive', 'strained', 'good', 'personal', 'different', 'same', 'aware', 'proactive', 'important', 'same', 'other', 'general', 'confident', 'right', 'special', 'whole', 'most', 'déjà', 'new', 'logan', 'entrenched', 'long', 'sid', 'insatiable', 'better', 'sure', 'many', 'green', 'other', 'defensive', 'worse', 'dominant', 'most', 'total', 'professional', 'top', 'last', 'false', 'good', 'good', 'defensive', 'second', 'good', 'offensive', 'neutral', 'wide', 'good', 'defensive', 'good', 'underrated', 'good', 'most', 'impossible', 'associate', 'fair', 'several', 'overall', 'whole', 'less', 'capable', 'defensive', 'old', 'biggest', 'first', 'much', 'final', 'late', 'open', 'whole', 'other', 'older', 'productive', 'best', 'thankful', 'competitive', 'transformative', 'huge', 'other', 'better', 'good', 'fourth', 'good', 'long', 'same', 'other', 'close', 'close', 'able', 'better', 'second', 'familiar', 'favorite', 'old', 'less', 'good', 'genuine', 'offensive', 'incredible', 'complete', 'good', 'good', 'beloved', 'big', 'many', 'other', 'indicative', 'fearless', 'fearful', 'vocal', 'memorable', 'first', 'first', 'fifth', 'little', 'same', 'best', 'old', 'youngest', 'favorite', 'good', 'big', 'big', 'clean', 'much', 'childhood', 'great', 'greatest', 'good', 'first', 'genaro', 'old', 'first', 'consecutive', 'perfect', 'professional', 'rapper', 'first', 'young', 'young', 'genaro', 'first', 'memorable', 'super', 'surreal', 'cool', 'little', 'super', 'able', 'high', 'cool', 'such', 'old', 'insane', 'first', 'last', 'excited', 'anxious', 'nervous', 'different', 'first', 'lone', 'first', 'top', 'able', 'young', 'bad', 'unique', '19th', 'same', 'open', 'next',  ...
# Mahomes
# ['future', 'top', 'more', 'patrick', 'recent', 'top', 'starter', 'top', 'top', 'justin', 'first', 'rough', 'next', 'tough', 'surprising', 'more', 'consecutive', 'allen', 'top', 'lower', 'cautious', 'past', 'current', 'several', 'top', 'tough', 'worthy', 'single', 'past', 'overall', 'consistent', 'wide', 'top', 'next', 'incredible', '49er', 'christian', 'alone', 'top', 'silly', 'many', 'fine', 'right', 'safe', 'cautious', 'quiet', 'consecutive', 'due', 'high', 'first', 'oblique', 'good', 'little', 'overall', 'top', 'quiet', 'wide', 'overall', 'top', 'wide', 'consistent', 'durable', 'flex', 'eligible', 'high', 'safe', 'cautious', 'considerable', 'top', 'top', 'tight', 'reasonable', 'deep', 'tight', 'overall', 'top', 'hard', 'tight', 'important', 'offensive', 'second', 'highest', 'happy', 'most', 'offensive', 'previous', 'good', 'right', 'right', 'little', 'positive', '15th', 'more', 'such', 'best', 'double', 'significant', 'second', 'important', 'big', 'first', 'first', 'next', 'second', 'first', 'final', 'last', 'first', 'wide', 'regular', 'last', 'active', 'biggest', 'fourth', 'close', 'breakthrough', 'wide', 'second', 'vertical', 'great', 'receiver', 'single', 'valuable', 'real', 'first', 'top', 'valuable', 'super', 'small', 'top', 'classic', 'super', 'same', 'top', 'different', 'early', 'narrow', 'upcoming', 'black', 'due', 'likely', 'top', 'respective', 'top', 'next', 'best', 'difficult', 'typical', 'average', 'second', 'next', 'last', 'narrow', 'philly', 'sixth', 'long', 'good', 'best', 'more', 'second', 'initial', 'first', 'trent', 'aggressive', 'top', 'impressive', 'primary', 'brown', 'early', 'key', 'wide', 'pressing', 'worse', 'unable', 'healthy', 'consistent', 'able', 'second', 'first', 'former', 'weekly', 'super', 'last', 'needy', 'free', 'tight', 'dominant', 'impactful', 'last', 'closer', 'future', 'solid', 'last', 'better', 'many', 'snap', 'high', 'first', 'offensive', 'close', 'great', 'snap', 'more', 'other', 'offensive', 'entire', 'snap', 'most', 'best', 'top', 'many', 'next', 'easiest', 'top', 'tricky', 'easier', 'single', 'best', 'aforementioned', 'pretty', 'necessary', 'top', 'most', 'late', 'zay', 'open', 'consecutive', 'more', 'ending', 'vulnerable', 'long', 'dominant', 'final', 'sloppy', 'best', 'dominant', 'early', 'multiple', 'impressive', 'only', 'other', 'more', 'such', 'last', 'single', 'super', 'other', 'good', 'several', 'frustrating', 'most', 'inclined', 'dominant', 'early', 'few', 'defensive', 'short', 'most', 'able', 'big', 'long', 'steady', 'big', 'key', 'final', 'meaningful', 'defensive', 'inactive', 'free', 'able', 'other', 'biggest', 'backup', 'different', 'versatile', 'special', 'late', 'trayvon', 'defensive', 'hard', 'more', 'first', 'defensive', 'first', 'fourth', 'open', 'fourth', 'quick', 'particular', 'intentional', 'backup', 'other', 'free', 'exotic', 'defensive', 'final', 'incredible', 'high', 'latter', 'sixth', 'good', 'healthy', 'homegrown', 'fine', 'other', 'huge', 'last', 'free', 'stellar', 'best', 'bigger', 'greatest', 'recent', 'solid', 'interior', 'likely', 'long', 'pro', 'many', 'pro', 'interior', 'fourth', 'madubuike', 'unblockable', 'offensive', 'next', 'high', 'metric', 'second', 'most', 'defensive', 'able', 'marcus', 'murkier', 'most', 'tight', 'regular', 'last', 'young', 'top', 'primary', 'tight', 'high', 'next', 'speedy', 'big', 'quiet', 'lead', 'free', 'important', 'healthy', 'recent', 'best', 'essential', 'past', 'pretty', 'healthy', 'next', 'toughest', 'final', 'straight', 'about', 'third', 'top', 'better', 'much', 'vulnerable', 'different', 'last', 'ramsey', 'valuable', 'worst', 'realistic', 'friendly', 'patrick', 'other', 'next', 'last', 'generous', 'tough', 'such', 'easier', 'able', 'second', 'able', 'great', 'defensive', 'past', 'extra', 'modest', 'more', 'best', 'top', 'sixth', 'singular', 'third', 'infamous', 'same', 'physical', 'pro', 'straight', 'more', 'worse', 'oblique', 'ramsey', 'underrated', 'recent', 'defensive', 'larger', 'free', 'possible', 'offensive' ...

# %%
# implement lemmatization

from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

messi_lemmatized = [lemmatizer.lemmatize(w) for w in messitokens]
lebron_lemmatized = [lemmatizer.lemmatize(w) for w in lebrontokens]
mahomes_lemmatized = [lemmatizer.lemmatize(w) for w in mahomestokens]
crosby_lemmatized = [lemmatizer.lemmatize(w) for w in crosbytokens]
trout_lemmatized = [lemmatizer.lemmatize(w) for w in trouttokens]

messi_nostopwords = [w for w in messi_lemmatized if w not in stopwords]
lebron_nostopwords = [w for w in lebron_lemmatized if w not in stopwords]
mahomes_nostopwords = [w for w in mahomes_lemmatized if w not in stopwords]
crosby_nostopwords = [w for w in crosby_lemmatized if w not in stopwords]
trout_nostopwords = [w for w in trout_lemmatized if w not in stopwords]

# %%
# building word clouds w stopwords

print('Messi Word Cloud')

fdist = nltk.FreqDist(messi_lemmatized)
print("\nFrequency Distribution")
print(fdist.most_common(20))
print(" ")

messitext = " ".join(messi_lemmatized)                                                                                                                                                                
wordcloud = WordCloud(max_font_size=40).generate(messitext)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
# plt.savefig('img/messi.png')
plt.show()

print('Lebron Word Cloud')

fdist = nltk.FreqDist(lebron_lemmatized)
print("\nFrequency Distribution")
print(fdist.most_common(20))
print(" ")

lebrontext = " ".join(lebron_lemmatized)                                                                                                                                                             
wordcloud = WordCloud(max_font_size=40).generate(lebrontext)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
# plt.savefig('img/lebron.png')
plt.show()

print('Mahomes Word Cloud')

fdist = nltk.FreqDist(mahomes_lemmatized)
print("\nFrequency Distribution")
print(fdist.most_common(20))
print(" ")

mahomestext = " ".join(mahomes_lemmatized)                                                                                                                                                             
wordcloud = WordCloud(max_font_size=40).generate(mahomestext)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
# plt.savefig('img/mahomes.png')
plt.show()

print('Crosby Word Cloud')

fdist = nltk.FreqDist(crosby_lemmatized)
print("\nFrequency Distribution")
print(fdist.most_common(20))
print(" ")

crosbytext = " ".join(crosby_lemmatized)                                                                                                                                                             
wordcloud = WordCloud(max_font_size=40).generate(crosbytext)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
# plt.savefig('img/crosby.png')
plt.show()

print('Trout Word Cloud')

fdist = nltk.FreqDist(trout_lemmatized)
print("\nFrequency Distribution")
print(fdist.most_common(20))
print(" ")

trouttext = " ".join(trout_lemmatized)                                                                                                                                                             
wordcloud = WordCloud(max_font_size=40).generate(trouttext)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
# plt.savefig('img/trout.png')
plt.show()
# Out:
# Messi Word Cloud
#
# Frequency Distribution
# [('the', 11868), (',', 10487), ('.', 8404), ('a', 5662), ('to', 5320), ('in', 5147), ('and', 4529), ('of', 3909), ("'s", 3353), ('messi', 2523), ('that', 2287), ('for', 2262), ('he', 2193), ('on', 2175), ('it', 2027), ('``', 1964), ('with', 1903), ("''", 1779), ('miami', 1778), ('is', 1755)]
# Lebron Word Cloud
#
# Frequency Distribution
# [('the', 3273), (',', 2619), ('.', 2324), ('a', 1476), ('to', 1472), ('in', 1294), ('and', 1257), ('of', 982), ("'s", 635), ('his', 629), ('he', 604), ('with', 524), ('james', 509), ('for', 502), ('that', 500), ('``', 497), ("''", 468), ('game', 446), ('it', 445), ('on', 443)]
# Mahomes Word Cloud
#
# Frequency Distribution
# [('the', 6112), (',', 5433), ('.', 4822), ('a', 3130), ('to', 2536), ('in', 2493), ('and', 2455), ('of', 1839), ('he', 1447), ("'s", 1357), ('for', 1132), ('that', 1041), ('is', 952), ('with', 938), ('it', 906), ('his', 889), ('(', 795), (')', 795), ('on', 785), ('season', 736)]
# Crosby Word Cloud
#
# Frequency Distribution
# [('the', 1204), ('.', 1054), (',', 1013), ('a', 571), ('to', 536), ('in', 477), ('and', 471), ('of', 385), ("'s", 318), ('he', 280), ('for', 233), ('that', 229), ('``', 216), ('his', 215), ("''", 211), ('with', 207), ('wa', 207), ('crosby', 190), ('it', 181), ('on', 180)]
# Trout Word Cloud
#
# Frequency Distribution
# [('the', 4662), (',', 4573), ('.', 3583), ('a', 2397), ('in', 1993), ('and', 1933), ('to', 1834), ('of', 1560), ('he', 1319), ("'s", 1133), ('his', 917), ('for', 776), ('that', 767), ('with', 717), ('is', 690), ('it', 683), ('on', 662), (':', 627), ('trout', 560), ('season', 534)]

# %%
# building word clouds w/o stopwords

print('Messi Word Cloud')

fdist = nltk.FreqDist(messi_nostopwords)
print("\nFrequency Distribution")
print(fdist.most_common(20))
print(" ")

messitext = " ".join(messi_nostopwords)                                                                                                                                                                
wordcloud = WordCloud(max_font_size=40).generate(messitext)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
# plt.savefig('img/messi.png')
plt.show()

print('Lebron Word Cloud')

fdist = nltk.FreqDist(lebron_nostopwords)
print("\nFrequency Distribution")
print(fdist.most_common(20))
print(" ")

lebrontext = " ".join(lebron_nostopwords)                                                                                                                                                             
wordcloud = WordCloud(max_font_size=40).generate(lebrontext)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
# plt.savefig('img/lebron.png')
plt.show()

print('Mahomes Word Cloud')

fdist = nltk.FreqDist(mahomes_nostopwords)
print("\nFrequency Distribution")
print(fdist.most_common(20))
print(" ")

mahomestext = " ".join(mahomes_nostopwords)                                                                                                                                                             
wordcloud = WordCloud(max_font_size=40).generate(mahomestext)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
# plt.savefig('img/mahomes.png')
plt.show()

print('Crosby Word Cloud')

fdist = nltk.FreqDist(crosby_nostopwords)
print("\nFrequency Distribution")
print(fdist.most_common(20))
print(" ")

crosbytext = " ".join(crosby_nostopwords)                                                                                                                                                             
wordcloud = WordCloud(max_font_size=40).generate(crosbytext)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
# plt.savefig('img/crosby.png')
plt.show()

print('Trout Word Cloud')

fdist = nltk.FreqDist(trout_nostopwords)
print("\nFrequency Distribution")
print(fdist.most_common(20))
print(" ")

trouttext = " ".join(trout_nostopwords)                                                                                                                                                             
wordcloud = WordCloud(max_font_size=40).generate(trouttext)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
# plt.savefig('img/trout.png')
plt.show()
# Out:
# Messi Word Cloud
#
# Frequency Distribution
# [('messi', 2523), ('miami', 1778), ('game', 1229), ('team', 1227), ('cup', 1144), ('league', 964), ('said', 943), ('inter', 864), ('player', 847), ('ml', 771), ('season', 699), ('goal', 680), ('world', 628), ('play', 626), ('match', 621), ('first', 593), ('one', 561), ('club', 540), ('argentina', 530), ('win', 504)]
# Lebron Word Cloud
#
# Frequency Distribution
# [('james', 509), ('game', 446), ('season', 375), ('team', 288), ('lakers', 281), ('said', 244), ('point', 209), ('year', 202), ('player', 177), ('nba', 173), ('first', 171), ('one', 164), ('final', 157), ('time', 126), ('last', 125), ('play', 121), ('davis', 117), ('lebron', 114), ('would', 112), ('bronny', 112)]
# Mahomes Word Cloud
#
# Frequency Distribution
# [('season', 736), ('game', 651), ('chief', 492), ('mahomes', 465), ('year', 452), ('quarterback', 375), ('team', 372), ('yard', 360), ('player', 339), ('nfl', 329), ('said', 310), ('one', 308), ('first', 297), ('time', 296), ('last', 295), ('play', 272), ('week', 262), ('two', 252), ('get', 246), ('top', 241)]
# Crosby Word Cloud
#
# Frequency Distribution
# [('crosby', 190), ('game', 175), ('penguin', 128), ('season', 124), ('year', 124), ('said', 120), ('team', 99), ('player', 87), ('first', 72), ('pittsburgh', 72), ('time', 71), ('nhl', 59), ('one', 58), ('point', 54), ('karlsson', 51), ('million', 50), ('two', 48), ('last', 48), ('would', 47), ('cup', 46)]
# Trout Word Cloud
#
# Frequency Distribution
# [('trout', 560), ('season', 534), ('game', 456), ('angel', 442), ('year', 355), ('team', 317), ('said', 303), ('player', 288), ('run', 279), ('ohtani', 262), ('hit', 238), ('first', 235), ('one', 232), ('time', 215), ('last', 211), ('league', 198), ('two', 188), ('home', 180), ('million', 179), ('best', 166)]

# %%
def print_common_bigrams(tokenlist):
    
    bigrams = nltk.ngrams(tokenlist, 2)
    bigramlist = list(bigrams)
    
    # print out most frequent bigrams
    bigramfreq = nltk.FreqDist(bigramlist)
    top10bigrams = bigramfreq.most_common(10)
    top50bigrams = bigramfreq.most_common(50)

    # part a)
    print('** Most frequent bigrams **')
    for x in top10bigrams:
        print(x[0][0], x[0][1])

    
    # part b)
    print('\n** Most frequent bigrams with no stop words **')
    for x in top50bigrams:
        if x[0][0].lower() not in stoplist and x[0][1].lower() not in stoplist:
            print(x[0][0], x[0][1])


print('Messi Bigrams')
print_common_bigrams(messi_lemmatized)
print('\nLebron Bigrams')
print_common_bigrams(lebron_lemmatized)
print('\nTrout Bigrams')
print_common_bigrams(trout_lemmatized)
print('\nCrosby Bigrams')
print_common_bigrams(crosby_lemmatized)
print('\nMahomes Bigrams')
print_common_bigrams(mahomes_lemmatized)
# Out:
# Messi Bigrams
# ** Most frequent bigrams **
# in the
# . ``
# of the
# inter miami
# , ''
# , and
# . ''
# . the
# , but
# for the
#
# ** Most frequent bigrams with no stop words **
# inter miami
# world cup
# league cup
# lionel messi
#
# Lebron Bigrams
# ** Most frequent bigrams **
# in the
# . ``
# of the
# , ''
# . ''
# the lakers
# to the
# , and
# . the
# on the
#
# ** Most frequent bigrams with no stop words **
# los angeles
# lebron james
# james said
#
# Trout Bigrams
# ** Most frequent bigrams **
# in the
# of the
# . ``
# . the
# , but
# the angel
# . he
# he 's
# , and
# for the
#
# ** Most frequent bigrams with no stop words **
# home run
# los angeles
# mike trout
#
# Crosby Bigrams
# ** Most frequent bigrams **
# . ``
# of the
# in the
# . the
# . ''
# , ''
# the penguin
# he 's
# , and
# said .
#
# ** Most frequent bigrams with no stop words **
# stanley cup
# sidney crosby
# year signed
#
# Mahomes Bigrams
# ** Most frequent bigrams **
# in the
# of the
# . ``
# . the
# , but
# , and
# . he
# the chief
# he 's
# for the
#
# ** Most frequent bigrams with no stop words **
# super bowl
# kansa city
# last season

# %%
# import statement
from nltk.collocations import *

# Create the object you need to get collocations.
bigram_measures = nltk.collocations.BigramAssocMeasures()

def print_collocations(tokenlist):

    finder = BigramCollocationFinder.from_words(tokenlist)
    finder.apply_freq_filter(2)
    print('** Common Collocations **')
    for c in finder.nbest(bigram_measures.pmi, 10):
        print(" ".join(c))

print('Messi Collocations')
print_collocations(messi_lemmatized)
print('\nLebron Collocations')
print_collocations(lebron_lemmatized)
print('\nTrout Collocations')
print_collocations(trout_lemmatized)
print('\nCrosby Collocations')
print_collocations(crosby_lemmatized)
print('\nMahomes Collocations')
print_collocations(mahomes_lemmatized)
# Out:
# Messi Collocations
# ** Common Collocations **
# 2-1. talles
# button-up collar
# cuatro grandes
# groupe amaury
# marius bulter
# michel platini
# talles magno
# trent alexander-arnold
# warren zaire-emery
# 'hot lip
#
# Lebron Collocations
# ** Common Collocations **
# alperen sengun
# bona fide
# collective bargaining
# concussion protocol
# hakeem olajuwon
# jason kidd
# kentavious caldwell-pope
# lisa leslie
# madison square
# mo bamba
#
# Trout Collocations
# ** Common Collocations **
# bryson stott
# bud selig
# carolina reaper
# cedric mullins
# charles barkley
# domestic violence
# framber valdez
# free-swinging hacker
# kendrys morale
# kodai senga
#
# Crosby Collocations
# ** Common Collocations **
# cartilage transplant
# conn smythe
# fair amount
# further specific
# gold medal
# greg wyshynski
# hat trick
# in-depth statistical
# kasperi kapanen
# la vega
#
# Mahomes Collocations
# ** Common Collocations **
# dresser winn
# edmonton oiler
# external defibrillator
# foyesade oluokun
# hand-eye coordination
# j.k. dobbin
# jameis winston
# khalil mack
# lionel messi
# nico collins

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from pathlib import Path
import pandas as pd
import glob

index=['Messi', 'Lebron', 'Trout', 'Crosby', 'Mahomes']
alltexts = [" ".join(messi_nostopwords), " ".join(lebron_nostopwords), " ".join(trout_nostopwords), " ".join(crosby_nostopwords), " ".join(mahomes_nostopwords),]

tfidf_vectorizer = TfidfVectorizer(input='content', stop_words='english')
tfidf_vector = tfidf_vectorizer.fit_transform(alltexts)

tfidf_df = pd.DataFrame(tfidf_vector.toarray(), index=index, columns=tfidf_vectorizer.get_feature_names_out())
tfidf_df = tfidf_df.stack().reset_index()
tfidf_df = tfidf_df.rename(columns={0:'tfidf', 'level_0': 'document', 'level_1': 'term'})
top_terms = tfidf_df.sort_values(by=['document', 'tfidf'], ascending=[True, False]).groupby(['document']).head(10)

top_terms
# Out:
#       document         term     tfidf
# 44672   Crosby       crosby  0.416764
# 50360   Crosby      penguin  0.339095
# 46652   Crosby         game  0.294979
# 54778   Crosby         year  0.240640
# 52142   Crosby       season  0.203380
# 51938   Crosby         said  0.189407
# 53433   Crosby         team  0.155252
# 53176   Crosby     sullivan  0.143358
# 53632   Crosby         time  0.138174
# 50570   Crosby       player  0.135069
# 20542   Lebron        james  0.374209
# 19226   Lebron         game  0.352154
# 24716   Lebron       season  0.303632
# 26007   Lebron         team  0.216145
# 20962   Lebron       lakers  0.208057
# 27352   Lebron         year  0.200706
# 23179   Lebron        point  0.183796
# 24512   Lebron         said  0.179385
# 16118   Lebron       bronny  0.172801
# 23144   Lebron       player  0.133069
# 65855  Mahomes       season  0.315558
# 60365  Mahomes         game  0.282858
# 62569  Mahomes      mahomes  0.267712
# 57741  Mahomes        chief  0.237773
# 68491  Mahomes         year  0.227267
# 68481  Mahomes         yard  0.174947
# 67146  Mahomes         team  0.160640
# 64768  Mahomes  quarterback  0.155735
# 64283  Mahomes       player  0.139385
# 63418  Mahomes          nfl  0.137750
# 8063     Messi        messi  0.439109
# 8089     Messi        miami  0.308292
# 5513     Messi         game  0.225862
# 12294    Messi         team  0.215148
# 6677     Messi        inter  0.209846
# 3582     Messi          cup  0.200286
# 8218     Messi           ml  0.187259
# 7336     Messi       league  0.169872
# 10799    Messi         said  0.162959
# 7857     Messi      martino  0.151592
# 40174    Trout        trout  0.457262
# 38429    Trout       season  0.263327
# 32939    Trout         game  0.236368
# 28838    Trout        angel  0.212779
# 41065    Trout         year  0.208928
# 36205    Trout       ohtani  0.177267
# 39720    Trout         team  0.154530
# 38169    Trout          run  0.147790
# 38225    Trout         said  0.145865
# 36857    Trout       player  0.139125

# %%
# this code will create the heatmap 

import altair as alt
import numpy as np


# adding a little randomness to break ties in term ranking
top_tfidf_plusRand = top_terms.copy()
top_tfidf_plusRand['tfidf'] = top_tfidf_plusRand['tfidf'] + np.random.rand(top_terms.shape[0])*0.0001

# base for all visualizations, with rank calculation
base = alt.Chart(top_tfidf_plusRand).encode(
    x = 'rank:O',
    y = 'document:N'
).transform_window(
    rank = "rank()",
    sort = [alt.SortField("tfidf", order="descending")],
    groupby = ["document"],
)

# heatmap specification
heatmap = base.mark_rect().encode(
    color = 'tfidf:Q'
)

# text labels, white for darker heatmap colors
text = base.mark_text(baseline='middle').encode(
    text = 'term:N',
    color = alt.condition(alt.datum.tfidf >= 0.23, alt.value('white'), alt.value('black'))
)

# display the three superimposed visualizations
(heatmap + text).properties(width = 600)
# Out:
# alt.LayerChart(...)

# %%
# tfidf for adjectives

index=['Messi', 'Lebron', 'Trout', 'Crosby', 'Mahomes']
alltexts = [" ".join(adjectives_per_text[0]), " ".join(adjectives_per_text[1]), " ".join(adjectives_per_text[2]), " ".join(adjectives_per_text[3]), " ".join(adjectives_per_text[4]),]

tfidf_vectorizer = TfidfVectorizer(input='content', stop_words='english')
tfidf_vector = tfidf_vectorizer.fit_transform(alltexts)

tfidf_df = pd.DataFrame(tfidf_vector.toarray(), index=index, columns=tfidf_vectorizer.get_feature_names_out())
tfidf_df = tfidf_df.stack().reset_index()
tfidf_df = tfidf_df.rename(columns={0:'tfidf', 'level_0': 'document', 'level_1': 'term'})
top_terms = tfidf_df.sort_values(by=['document', 'tfidf'], ascending=[True, False]).groupby(['document']).head(10)

top_terms
# Out:
#       document       term     tfidf
# 7729    Crosby       good  0.339313
# 8606    Crosby     second  0.307503
# 8262    Crosby        old  0.243881
# 7679    Crosby       free  0.212071
# 8654    Crosby        sid  0.200274
# 7134    Crosby       best  0.180260
# 7738    Crosby      great  0.169657
# 8876    Crosby      total  0.162978
# 7707    Crosby    general  0.159053
# 7784    Crosby       high  0.159053
# 2907    Lebron     durant  0.344546
# 2564    Lebron       best  0.267335
# 3692    Lebron        old  0.251375
# 2568    Lebron        big  0.235415
# 4036    Lebron     second  0.211474
# 2635    Lebron    cardiac  0.209430
# 3923    Lebron    regular  0.203494
# 4471    Lebron        usc  0.184220
# 2393    Lebron       able  0.167583
# 3214    Lebron       high  0.167583
# 9419   Mahomes       best  0.430747
# 11082  Mahomes      super  0.294721
# 10891  Mahomes     second  0.266819
# 10585  Mahomes    overall  0.223221
# 10014  Mahomes       good  0.211014
# 11388  Mahomes       wide  0.184855
# 9679   Mahomes  defensive  0.179623
# 10541  Mahomes  offensive  0.179623
# 11141  Mahomes      tight  0.171135
# 9423   Mahomes        big  0.169160
# 772      Messi      final  0.467416
# 279      Messi       best  0.291728
# 1359     Messi        new  0.238588
# 1254     Messi      messi  0.225317
# 1751     Messi     second  0.206053
# 1407     Messi        old  0.196293
# 874      Messi       good  0.168096
# 201      Messi  argentine  0.152487
# 824      Messi       free  0.129055
# 1469     Messi       past  0.129055
# 4849     Trout       best  0.373755
# 5974     Trout     ohtani  0.290710
# 5444     Trout       good  0.253526
# 6321     Trout     second  0.253526
# 6250     Trout      right  0.216935
# 4853     Trout        big  0.203866
# 6039     Trout       past  0.182957
# 5714     Trout       left  0.182322
# 5788     Trout      major  0.180343
# 5394     Trout       free  0.162048

# %%
# adding a little randomness to break ties in term ranking
top_tfidf_plusRand = top_terms.copy()
top_tfidf_plusRand['tfidf'] = top_tfidf_plusRand['tfidf'] + np.random.rand(top_terms.shape[0])*0.0001

# base for all visualizations, with rank calculation
base = alt.Chart(top_tfidf_plusRand).encode(
    x = 'rank:O',
    y = 'document:N'
).transform_window(
    rank = "rank()",
    sort = [alt.SortField("tfidf", order="descending")],
    groupby = ["document"],
)

# heatmap specification
heatmap = base.mark_rect().encode(
    color = 'tfidf:Q'
)

# text labels, white for darker heatmap colors
text = base.mark_text(baseline='middle').encode(
    text = 'term:N',
    color = alt.condition(alt.datum.tfidf >= 0.23, alt.value('white'), alt.value('black'))
)

# display the three superimposed visualizations
(heatmap + text).properties(width = 600)
# Out:
# alt.LayerChart(...)
